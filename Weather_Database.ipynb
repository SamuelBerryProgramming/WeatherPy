# %%
import numpy as np
from citipy import citipy
import pandas as pd
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the API key.
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Min Temp": city_min_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | senador pompeu
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | guasdualito
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | husavik
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | ovalle
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | margate
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | ketchikan
# Processing Record 22 of Set 1 | santo domingo suchitepequez
# Processing Record 23 of Set 1 | belaya gora
# Processing Record 24 of Set 1 | azangaro
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | tyrma
# Processing Record 29 of Set 1 | grindavik
# Processing Record 30 of Set 1 | san pedro
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | asfi
# Processing Record 34 of Set 1 | labuhan
# Processing Record 35 of Set 1 | srednekolymsk
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | kasongo
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | lazaro cardenas
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | ajdabiya
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | bandarbeyla
# Processing Record 49 of Set 1 | lorengau
# Processing Record 50 of Set 1 | dhidhdhoo
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | bilibino
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | lafiagi
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | tukrah
# Processing Record 9 of Set 2 | pudozh
# Processing Record 10 of Set 2 | poum
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | saint-joseph
# Processing Record 15 of Set 2 | balabac
# Processing Record 16 of Set 2 | nosy varika
# Processing Record 17 of Set 2 | mezhdurechensk
# Processing Record 18 of Set 2 | kaseda
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | ha giang
# Processing Record 23 of Set 2 | swinoujscie
# Processing Record 24 of Set 2 | bay roberts
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | tiarei
# Processing Record 29 of Set 2 | takoradi
# Processing Record 30 of Set 2 | bardiyah
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | vao
# Processing Record 33 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | meulaboh
# Processing Record 37 of Set 2 | culleredo
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | mut
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | grafton
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | kollam
# Processing Record 44 of Set 2 | whitehorse
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | biltine
# Processing Record 47 of Set 2 | kurilsk
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | novokizhinginsk
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | umm lajj
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | ust-ishim
# Processing Record 6 of Set 3 | namibe
# Processing Record 7 of Set 3 | lakhdenpokhya
# Processing Record 8 of Set 3 | frederico westphalen
# Processing Record 9 of Set 3 | sanmenxia
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | kununurra
# Processing Record 12 of Set 3 | sorland
# Processing Record 13 of Set 3 | pishva
# Processing Record 14 of Set 3 | amethi
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | walvis bay
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | vila velha
# Processing Record 19 of Set 3 | kenora
# Processing Record 20 of Set 3 | presidencia roque saenz pena
# Processing Record 21 of Set 3 | belmonte
# Processing Record 22 of Set 3 | kapit
# Processing Record 23 of Set 3 | kahului
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | gagarin
# Processing Record 26 of Set 3 | rjukan
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | cam ranh
# Processing Record 29 of Set 3 | rocha
# Processing Record 30 of Set 3 | aksu
# Processing Record 31 of Set 3 | mountain home
# Processing Record 32 of Set 3 | aktanysh
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | hovd
# Processing Record 36 of Set 3 | plettenberg bay
# Processing Record 37 of Set 3 | tripoli
# Processing Record 38 of Set 3 | naze
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | aswan
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | campo verde
# Processing Record 43 of Set 3 | kaeo
# Processing Record 44 of Set 3 | tautira
# Processing Record 45 of Set 3 | olafsvik
# Processing Record 46 of Set 3 | loralai
# Processing Record 47 of Set 3 | hobyo
# Processing Record 48 of Set 3 | terney
# Processing Record 49 of Set 3 | oneida
# Processing Record 50 of Set 3 | harper
# Processing Record 1 of Set 4 | dwarka
# Processing Record 2 of Set 4 | kangaatsiaq
# Processing Record 3 of Set 4 | nacala
# Processing Record 4 of Set 4 | aipe
# Processing Record 5 of Set 4 | yar-sale
# Processing Record 6 of Set 4 | port lincoln
# Processing Record 7 of Set 4 | zunyi
# Processing Record 8 of Set 4 | honolulu
# Processing Record 9 of Set 4 | okhotsk
# Processing Record 10 of Set 4 | marienburg
# Processing Record 11 of Set 4 | lasa
# Processing Record 12 of Set 4 | hilo
# Processing Record 13 of Set 4 | aykhal
# Processing Record 14 of Set 4 | yulara
# Processing Record 15 of Set 4 | kruisfontein
# Processing Record 16 of Set 4 | nuuk
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | antofagasta
# Processing Record 19 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | aklavik
# Processing Record 22 of Set 4 | fallon
# Processing Record 23 of Set 4 | teacapan
# Processing Record 24 of Set 4 | pazardzik
# City not found. Skipping...
# Processing Record 25 of Set 4 | turmalina
# Processing Record 26 of Set 4 | diffa
# Processing Record 27 of Set 4 | kurmanayevka
# Processing Record 28 of Set 4 | skjaerhollen
# City not found. Skipping...
# Processing Record 29 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 4 | porto murtinho
# Processing Record 31 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 4 | palmer
# Processing Record 33 of Set 4 | abha
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | san quintin
# Processing Record 36 of Set 4 | bodo
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | sokur
# Processing Record 39 of Set 4 | quesnel
# Processing Record 40 of Set 4 | jaguaribe
# Processing Record 41 of Set 4 | outlook
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | juneau
# Processing Record 44 of Set 4 | grand gaube
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | mayo
# Processing Record 47 of Set 4 | rio gallegos
# Processing Record 48 of Set 4 | puerto baquerizo moreno
# Processing Record 49 of Set 4 | great falls
# Processing Record 50 of Set 4 | kapoeta
# Processing Record 1 of Set 5 | coihaique
# Processing Record 2 of Set 5 | potrero del llano
# Processing Record 3 of Set 5 | santa maria do suacui
# Processing Record 4 of Set 5 | borskoye
# Processing Record 5 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 5 | manaure
# Processing Record 7 of Set 5 | port macquarie
# Processing Record 8 of Set 5 | thinadhoo
# Processing Record 9 of Set 5 | borazjan
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | ahuimanu
# Processing Record 12 of Set 5 | denpasar
# Processing Record 13 of Set 5 | bathsheba
# Processing Record 14 of Set 5 | aranos
# Processing Record 15 of Set 5 | bethel
# Processing Record 16 of Set 5 | pachino
# Processing Record 17 of Set 5 | villarrobledo
# Processing Record 18 of Set 5 | najran
# Processing Record 19 of Set 5 | barra dos coqueiros
# Processing Record 20 of Set 5 | tuskegee
# Processing Record 21 of Set 5 | fairbanks
# Processing Record 22 of Set 5 | alekseyevka
# Processing Record 23 of Set 5 | seoul
# Processing Record 24 of Set 5 | bandar-e lengeh
# Processing Record 25 of Set 5 | kuala terengganu
# Processing Record 26 of Set 5 | ponta do sol
# Processing Record 27 of Set 5 | serchhip
# Processing Record 28 of Set 5 | bulolo
# Processing Record 29 of Set 5 | san miguel el alto
# Processing Record 30 of Set 5 | sao joao da barra
# Processing Record 31 of Set 5 | veshenskaya
# Processing Record 32 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 5 | campos novos
# Processing Record 34 of Set 5 | tonantins
# Processing Record 35 of Set 5 | bharatpur
# Processing Record 36 of Set 5 | mitchell
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | cidreira
# Processing Record 39 of Set 5 | yellowknife
# Processing Record 40 of Set 5 | kasempa
# Processing Record 41 of Set 5 | bonavista
# Processing Record 42 of Set 5 | glendive
# Processing Record 43 of Set 5 | hervey bay
# Processing Record 44 of Set 5 | tuatapere
# Processing Record 45 of Set 5 | poso
# Processing Record 46 of Set 5 | salalah
# Processing Record 47 of Set 5 | csaszartoltes
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | suzun
# Processing Record 50 of Set 5 | klaksvik
# Processing Record 1 of Set 6 | svetlogorsk
# Processing Record 2 of Set 6 | northam
# Processing Record 3 of Set 6 | gao
# Processing Record 4 of Set 6 | rosa zarate
# Processing Record 5 of Set 6 | iberia
# Processing Record 6 of Set 6 | jibuti
# Processing Record 7 of Set 6 | larsnes
# Processing Record 8 of Set 6 | lae
# Processing Record 9 of Set 6 | anqing
# Processing Record 10 of Set 6 | severo-kurilsk
# Processing Record 11 of Set 6 | lompoc
# Processing Record 12 of Set 6 | zhezkazgan
# Processing Record 13 of Set 6 | rzhaksa
# Processing Record 14 of Set 6 | ville-marie
# Processing Record 15 of Set 6 | verona
# Processing Record 16 of Set 6 | la romana
# Processing Record 17 of Set 6 | san andres
# Processing Record 18 of Set 6 | jieshi
# Processing Record 19 of Set 6 | new norfolk
# Processing Record 20 of Set 6 | camacha
# Processing Record 21 of Set 6 | fukue
# Processing Record 22 of Set 6 | oktyabrskoye
# Processing Record 23 of Set 6 | talara
# Processing Record 24 of Set 6 | belyy yar
# Processing Record 25 of Set 6 | omboue
# Processing Record 26 of Set 6 | batagay
# Processing Record 27 of Set 6 | xuddur
# Processing Record 28 of Set 6 | faanui
# Processing Record 29 of Set 6 | dunedin
# Processing Record 30 of Set 6 | san cristobal
# Processing Record 31 of Set 6 | morondava
# Processing Record 32 of Set 6 | canakkale
# Processing Record 33 of Set 6 | luganville
# Processing Record 34 of Set 6 | vuktyl
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | kavaratti
# Processing Record 37 of Set 6 | conde
# Processing Record 38 of Set 6 | ucluelet
# Processing Record 39 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | araouane
# Processing Record 42 of Set 6 | flin flon
# Processing Record 43 of Set 6 | kalmunai
# Processing Record 44 of Set 6 | tignere
# Processing Record 45 of Set 6 | auki
# Processing Record 46 of Set 6 | quatre cocos
# Processing Record 47 of Set 6 | mangla
# Processing Record 48 of Set 6 | paracuru
# Processing Record 49 of Set 6 | swellendam
# Processing Record 50 of Set 6 | ozu
# Processing Record 1 of Set 7 | bagdarin
# Processing Record 2 of Set 7 | airai
# Processing Record 3 of Set 7 | mount gambier
# Processing Record 4 of Set 7 | loiza
# Processing Record 5 of Set 7 | san jeronimo
# Processing Record 6 of Set 7 | uthal
# Processing Record 7 of Set 7 | oleksandrivka
# Processing Record 8 of Set 7 | puerto ayacucho
# Processing Record 9 of Set 7 | kavieng
# Processing Record 10 of Set 7 | the valley
# Processing Record 11 of Set 7 | saurimo
# Processing Record 12 of Set 7 | berlevag
# Processing Record 13 of Set 7 | vytegra
# Processing Record 14 of Set 7 | port keats
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | marathon
# Processing Record 17 of Set 7 | asau
# Processing Record 18 of Set 7 | hamilton
# Processing Record 19 of Set 7 | sakakah
# Processing Record 20 of Set 7 | polunochnoye
# Processing Record 21 of Set 7 | sisimiut
# Processing Record 22 of Set 7 | manicore
# Processing Record 23 of Set 7 | pekalongan
# Processing Record 24 of Set 7 | sao filipe
# Processing Record 25 of Set 7 | geraldton
# Processing Record 26 of Set 7 | flinders
# Processing Record 27 of Set 7 | los llanos de aridane
# Processing Record 28 of Set 7 | yarada
# Processing Record 29 of Set 7 | jurado
# Processing Record 30 of Set 7 | menongue
# Processing Record 31 of Set 7 | angoche
# Processing Record 32 of Set 7 | saint anthony
# Processing Record 33 of Set 7 | oranjestad
# Processing Record 34 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 7 | saint-andre-avellin
# Processing Record 36 of Set 7 | aguimes
# Processing Record 37 of Set 7 | esperance
# Processing Record 38 of Set 7 | karaton
# Processing Record 39 of Set 7 | scottsbluff
# Processing Record 40 of Set 7 | krasnoshchekovo
# Processing Record 41 of Set 7 | pandamatenga
# Processing Record 42 of Set 7 | morehead
# Processing Record 43 of Set 7 | sao jose da coroa grande
# Processing Record 44 of Set 7 | ossora
# Processing Record 45 of Set 7 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 46 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 47 of Set 7 | nago
# Processing Record 48 of Set 7 | noumea
# Processing Record 49 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 8 | reconquista
# Processing Record 3 of Set 8 | beisfjord
# Processing Record 4 of Set 8 | nanortalik
# Processing Record 5 of Set 8 | broome
# Processing Record 6 of Set 8 | tessalit
# Processing Record 7 of Set 8 | tingo maria
# Processing Record 8 of Set 8 | nishihara
# Processing Record 9 of Set 8 | ngunguru
# Processing Record 10 of Set 8 | gat
# Processing Record 11 of Set 8 | ligayan
# Processing Record 12 of Set 8 | mareeba
# Processing Record 13 of Set 8 | irbeyskoye
# Processing Record 14 of Set 8 | kargopol
# Processing Record 15 of Set 8 | sambava
# Processing Record 16 of Set 8 | zyryanka
# Processing Record 17 of Set 8 | alekseyevsk
# Processing Record 18 of Set 8 | tecolutla
# Processing Record 19 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 8 | beringovskiy
# Processing Record 21 of Set 8 | coquimbo
# Processing Record 22 of Set 8 | clyde river
# Processing Record 23 of Set 8 | souillac
# Processing Record 24 of Set 8 | naushki
# Processing Record 25 of Set 8 | gunnedah
# Processing Record 26 of Set 8 | ikryanoye
# Processing Record 27 of Set 8 | monrovia
# Processing Record 28 of Set 8 | inhambane
# Processing Record 29 of Set 8 | katakwi
# Processing Record 30 of Set 8 | namatanai
# Processing Record 31 of Set 8 | zhoucheng
# Processing Record 32 of Set 8 | wanning
# Processing Record 33 of Set 8 | manadhoo
# Processing Record 34 of Set 8 | tezu
# Processing Record 35 of Set 8 | hofn
# Processing Record 36 of Set 8 | nantucket
# Processing Record 37 of Set 8 | hailey
# Processing Record 38 of Set 8 | saint pete beach
# Processing Record 39 of Set 8 | urazovo
# Processing Record 40 of Set 8 | paita
# Processing Record 41 of Set 8 | mangan
# Processing Record 42 of Set 8 | zheleznodorozhnyy
# Processing Record 43 of Set 8 | hvolsvollur
# Processing Record 44 of Set 8 | omvriaki
# Processing Record 45 of Set 8 | tocopilla
# Processing Record 46 of Set 8 | vardo
# Processing Record 47 of Set 8 | agronom
# Processing Record 48 of Set 8 | kargasok
# Processing Record 49 of Set 8 | wasilla
# Processing Record 50 of Set 8 | talaya
# Processing Record 1 of Set 9 | kabinda
# Processing Record 2 of Set 9 | oksovskiy
# Processing Record 3 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 4 of Set 9 | svetlaya
# Processing Record 5 of Set 9 | cabo san lucas
# Processing Record 6 of Set 9 | ginda
# Processing Record 7 of Set 9 | constitucion
# Processing Record 8 of Set 9 | katsuura
# Processing Record 9 of Set 9 | nalut
# Processing Record 10 of Set 9 | pullman
# Processing Record 11 of Set 9 | koshki
# Processing Record 12 of Set 9 | khandyga
# Processing Record 13 of Set 9 | karlskoga
# Processing Record 14 of Set 9 | henties bay
# Processing Record 15 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 9 | saldanha
# Processing Record 17 of Set 9 | salinopolis
# Processing Record 18 of Set 9 | port-gentil
# Processing Record 19 of Set 9 | jalu
# Processing Record 20 of Set 9 | macamic
# Processing Record 21 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 22 of Set 9 | naujamiestis
# Processing Record 23 of Set 9 | raudeberg
# Processing Record 24 of Set 9 | magog
# Processing Record 25 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 9 | rauma
# Processing Record 27 of Set 9 | marinha grande
# Processing Record 28 of Set 9 | encrucijada
# Processing Record 29 of Set 9 | luba
# Processing Record 30 of Set 9 | novo aripuana
# Processing Record 31 of Set 9 | kieta
# Processing Record 32 of Set 9 | vicksburg
# Processing Record 33 of Set 9 | coahuayana
# Processing Record 34 of Set 9 | raga
# Processing Record 35 of Set 9 | normandin
# Processing Record 36 of Set 9 | roald
# Processing Record 37 of Set 9 | ishigaki
# Processing Record 38 of Set 9 | banjar
# Processing Record 39 of Set 9 | santa rosa
# Processing Record 40 of Set 9 | padang
# Processing Record 41 of Set 9 | gorontalo
# Processing Record 42 of Set 9 | baie-saint-paul
# Processing Record 43 of Set 9 | santa isabel do rio negro
# Processing Record 44 of Set 9 | kuryk
# Processing Record 45 of Set 9 | borama
# City not found. Skipping...
# Processing Record 46 of Set 9 | portland
# Processing Record 47 of Set 9 | heihe
# Processing Record 48 of Set 9 | pangnirtung
# Processing Record 49 of Set 9 | sterling
# Processing Record 50 of Set 9 | oktyabrskiy
# Processing Record 1 of Set 10 | abay
# Processing Record 2 of Set 10 | podolsk
# Processing Record 3 of Set 10 | tiznit
# Processing Record 4 of Set 10 | ilhabela
# Processing Record 5 of Set 10 | piacabucu
# Processing Record 6 of Set 10 | pengcheng
# Processing Record 7 of Set 10 | laguna
# Processing Record 8 of Set 10 | taree
# Processing Record 9 of Set 10 | yeppoon
# Processing Record 10 of Set 10 | ternate
# Processing Record 11 of Set 10 | purpe
# Processing Record 12 of Set 10 | broadstairs
# Processing Record 13 of Set 10 | atambua
# Processing Record 14 of Set 10 | neiafu
# Processing Record 15 of Set 10 | malazgirt
# Processing Record 16 of Set 10 | dingle
# Processing Record 17 of Set 10 | timiryazevskiy
# Processing Record 18 of Set 10 | turayf
# Processing Record 19 of Set 10 | chapais
# Processing Record 20 of Set 10 | acapulco
# Processing Record 21 of Set 10 | arandis
# Processing Record 22 of Set 10 | el dorado
# Processing Record 23 of Set 10 | buala
# Processing Record 24 of Set 10 | xining
# Processing Record 25 of Set 10 | jasper
# Processing Record 26 of Set 10 | vestmannaeyjar
# Processing Record 27 of Set 10 | mikhaylovka
# Processing Record 28 of Set 10 | alihe
# Processing Record 29 of Set 10 | kampong thum
# Processing Record 30 of Set 10 | ak-dovurak
# Processing Record 31 of Set 10 | ninghai
# Processing Record 32 of Set 10 | sioux lookout
# Processing Record 33 of Set 10 | calama
# Processing Record 34 of Set 10 | akyab
# Processing Record 35 of Set 10 | trairi
# Processing Record 36 of Set 10 | mogadishu
# Processing Record 37 of Set 10 | quelimane
# Processing Record 38 of Set 10 | hanna
# Processing Record 39 of Set 10 | dicabisagan
# Processing Record 40 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 41 of Set 10 | rovaniemi
# Processing Record 42 of Set 10 | lodja
# Processing Record 43 of Set 10 | port hardy
# Processing Record 44 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 10 | rock sound
# Processing Record 46 of Set 10 | divnomorskoye
# Processing Record 47 of Set 10 | imbituba
# Processing Record 48 of Set 10 | fort nelson
# Processing Record 49 of Set 10 | baie-comeau
# Processing Record 50 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 11 | maragogi
# Processing Record 2 of Set 11 | el chimbo
# Processing Record 3 of Set 11 | nador
# Processing Record 4 of Set 11 | khasan
# Processing Record 5 of Set 11 | pljevlja
# Processing Record 6 of Set 11 | la seyne-sur-mer
# Processing Record 7 of Set 11 | bialogard
# Processing Record 8 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 11 | luena
# Processing Record 10 of Set 11 | havre-saint-pierre
# Processing Record 11 of Set 11 | okha
# Processing Record 12 of Set 11 | savannakhet
# Processing Record 13 of Set 11 | nizhniy odes
# Processing Record 14 of Set 11 | aja
# Processing Record 15 of Set 11 | makakilo city
# Processing Record 16 of Set 11 | natal
# Processing Record 17 of Set 11 | ceyhan
# Processing Record 18 of Set 11 | tomatlan
# Processing Record 19 of Set 11 | puri
# Processing Record 20 of Set 11 | dunyapur
# Processing Record 21 of Set 11 | carutapera
# Processing Record 22 of Set 11 | mount isa
# Processing Record 23 of Set 11 | yantarnyy
# Processing Record 24 of Set 11 | russell
# Processing Record 25 of Set 11 | santa maria
# Processing Record 26 of Set 11 | moyale
# Processing Record 27 of Set 11 | paka
# Processing Record 28 of Set 11 | kroya
# Processing Record 29 of Set 11 | madras
# Processing Record 30 of Set 11 | ugoofaaru
# Processing Record 31 of Set 11 | knysna
# Processing Record 32 of Set 11 | landeck
# Processing Record 33 of Set 11 | baruun-urt
# Processing Record 34 of Set 11 | yamada
# Processing Record 35 of Set 11 | kurchum
# Processing Record 36 of Set 11 | nsoko
# Processing Record 37 of Set 11 | dakar
# Processing Record 38 of Set 11 | pires do rio
# Processing Record 39 of Set 11 | destin
# Processing Record 40 of Set 11 | villa carlos paz
# Processing Record 41 of Set 11 | bati
# Processing Record 42 of Set 11 | narsaq
# Processing Record 43 of Set 11 | cockburn town
# Processing Record 44 of Set 11 | bumba
# Processing Record 45 of Set 11 | zaragoza
# Processing Record 46 of Set 11 | nha trang
# Processing Record 47 of Set 11 | praia da vitoria
# Processing Record 48 of Set 11 | moshkovo
# Processing Record 49 of Set 11 | sabang
# Processing Record 50 of Set 11 | keshorai patan
# Processing Record 1 of Set 12 | zhigansk
# Processing Record 2 of Set 12 | singkang
# Processing Record 3 of Set 12 | san miguel
# Processing Record 4 of Set 12 | tahoua
# Processing Record 5 of Set 12 | belozerskoye
# Processing Record 6 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 7 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 12 | villazon
# Processing Record 9 of Set 12 | braslav
# City not found. Skipping...
# Processing Record 10 of Set 12 | severo-yeniseyskiy
# Processing Record 11 of Set 12 | painesville
# Processing Record 12 of Set 12 | bjornevatn
# Processing Record 13 of Set 12 | bubaque
# Processing Record 14 of Set 12 | alice springs
# Processing Record 15 of Set 12 | ko samui
# Processing Record 16 of Set 12 | chatellerault
# Processing Record 17 of Set 12 | abu dhabi
# Processing Record 18 of Set 12 | chicama
# Processing Record 19 of Set 12 | aflao
# Processing Record 20 of Set 12 | buraydah
# Processing Record 21 of Set 12 | maldonado
# Processing Record 22 of Set 12 | independence
# Processing Record 23 of Set 12 | labuan
# Processing Record 24 of Set 12 | chamba
# Processing Record 25 of Set 12 | moree
# Processing Record 26 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 12 | maymyo
# Processing Record 28 of Set 12 | baffa
# Processing Record 29 of Set 12 | harbour breton
# Processing Record 30 of Set 12 | valparaiso
# Processing Record 31 of Set 12 | danszentmiklos
# Processing Record 32 of Set 12 | guerrero negro
# Processing Record 33 of Set 12 | idappadi
# Processing Record 34 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 12 | romitan
# Processing Record 39 of Set 12 | sandpoint
# Processing Record 40 of Set 12 | koraput
# Processing Record 41 of Set 12 | dubbo
# Processing Record 42 of Set 12 | yerbogachen
# Processing Record 43 of Set 12 | inta
# Processing Record 44 of Set 12 | douglas
# Processing Record 45 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 12 | saint-leu
# Processing Record 47 of Set 12 | kirakira
# Processing Record 48 of Set 12 | bowen
# Processing Record 49 of Set 12 | paamiut
# Processing Record 50 of Set 12 | saint-augustin
# Processing Record 1 of Set 13 | miles city
# Processing Record 2 of Set 13 | singaraja
# Processing Record 3 of Set 13 | harrison
# Processing Record 4 of Set 13 | maceio
# Processing Record 5 of Set 13 | beaumont
# Processing Record 6 of Set 13 | kondinskoye
# Processing Record 7 of Set 13 | marystown
# Processing Record 8 of Set 13 | galveston
# Processing Record 9 of Set 13 | vanimo
# Processing Record 10 of Set 13 | monte patria
# Processing Record 11 of Set 13 | cabra
# Processing Record 12 of Set 13 | acolla
# Processing Record 13 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 15 of Set 13 | leningradskiy
# Processing Record 16 of Set 13 | haines junction
# Processing Record 17 of Set 13 | ust-ordynskiy
# Processing Record 18 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 19 of Set 13 | ust-nera
# Processing Record 20 of Set 13 | sur
# Processing Record 21 of Set 13 | te anau
# Processing Record 22 of Set 13 | egvekinot
# Processing Record 23 of Set 13 | lima
# Processing Record 24 of Set 13 | richards bay
# Processing Record 25 of Set 13 | adre
# Processing Record 26 of Set 13 | smithers
# Processing Record 27 of Set 13 | yuli
# Processing Record 28 of Set 13 | pisco
# Processing Record 29 of Set 13 | yongan
# Processing Record 30 of Set 13 | pochutla
# Processing Record 31 of Set 13 | arlit
# Processing Record 32 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 33 of Set 13 | yangambi
# Processing Record 34 of Set 13 | mpongwe
# Processing Record 35 of Set 13 | marivan
# Processing Record 36 of Set 13 | batemans bay
# Processing Record 37 of Set 13 | quchan
# Processing Record 38 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 13 | nouadhibou
# Processing Record 40 of Set 13 | poya
# Processing Record 41 of Set 13 | porto novo
# Processing Record 42 of Set 13 | la baule-escoublac
# Processing Record 43 of Set 13 | port blair
# Processing Record 44 of Set 13 | kathmandu
# Processing Record 45 of Set 13 | muzhi
# Processing Record 46 of Set 13 | cochrane
# Processing Record 47 of Set 13 | butembo
# Processing Record 48 of Set 13 | kunming
# Processing Record 49 of Set 13 | yinchuan
# Processing Record 50 of Set 13 | cap-aux-meules
# Processing Record 1 of Set 14 | biak
# Processing Record 2 of Set 14 | bonham
# Processing Record 3 of Set 14 | edremit
# Processing Record 4 of Set 14 | sistranda
# Processing Record 5 of Set 14 | chokwe
# Processing Record 6 of Set 14 | atikokan
# Processing Record 7 of Set 14 | kanniyakumari
# Processing Record 8 of Set 14 | avera
# Processing Record 9 of Set 14 | ruteng
# Processing Record 10 of Set 14 | sebeta
# Processing Record 11 of Set 14 | kedrovyy
# Processing Record 12 of Set 14 | lichuan
# Processing Record 13 of Set 14 | korla
# Processing Record 14 of Set 14 | pemangkat
# Processing Record 15 of Set 14 | palana
# Processing Record 16 of Set 14 | moengo
# Processing Record 17 of Set 14 | whitecourt
# Processing Record 18 of Set 14 | jiaocheng
# Processing Record 19 of Set 14 | tromso
# Processing Record 20 of Set 14 | zhigalovo
# Processing Record 21 of Set 14 | khorramshahr
# Processing Record 22 of Set 14 | gizo
# Processing Record 23 of Set 14 | omutinskoye
# City not found. Skipping...
# Processing Record 24 of Set 14 | kushima
# Processing Record 25 of Set 14 | chenove
# Processing Record 26 of Set 14 | leshukonskoye
# Processing Record 27 of Set 14 | sao felix do xingu
# Processing Record 28 of Set 14 | limoges
# Processing Record 29 of Set 14 | dunmore town
# Processing Record 30 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 31 of Set 14 | milton keynes
# Processing Record 32 of Set 14 | maridi
# Processing Record 33 of Set 14 | lamas
# Processing Record 34 of Set 14 | booue
# Processing Record 35 of Set 14 | waingapu
# Processing Record 36 of Set 14 | tonekabon
# Processing Record 37 of Set 14 | sibolga
# Processing Record 38 of Set 14 | shalya
# Processing Record 39 of Set 14 | khomeyn
# Processing Record 40 of Set 14 | doha
# Processing Record 41 of Set 14 | qasigiannguit
# Processing Record 42 of Set 14 | concordia
# Processing Record 43 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 44 of Set 14 | whittlesea
# Processing Record 45 of Set 14 | shenzhen
# Processing Record 46 of Set 14 | kreuztal
# Processing Record 47 of Set 14 | jinchang
# Processing Record 48 of Set 14 | nome
# Processing Record 49 of Set 14 | kiruna
# Processing Record 50 of Set 14 | yingzhong
# City not found. Skipping...
# Processing Record 1 of Set 15 | sangar
# Processing Record 2 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 15 | hay river
# Processing Record 4 of Set 15 | sutton
# Processing Record 5 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 15 | we
# City not found. Skipping...
# Processing Record 7 of Set 15 | mahanoro
# Processing Record 8 of Set 15 | faya
# Processing Record 9 of Set 15 | high rock
# Processing Record 10 of Set 15 | seymchan
# Processing Record 11 of Set 15 | raozan
# City not found. Skipping...
# Processing Record 12 of Set 15 | olinda
# Processing Record 13 of Set 15 | kawalu
# Processing Record 14 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 15 of Set 15 | ust-kuyga
# Processing Record 16 of Set 15 | kichera
# Processing Record 17 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 15 | roma
# Processing Record 19 of Set 15 | kozlovo
# Processing Record 20 of Set 15 | marsa matruh
# Processing Record 21 of Set 15 | gilroy
# Processing Record 22 of Set 15 | lensk
# Processing Record 23 of Set 15 | panaba
# Processing Record 24 of Set 15 | jitra
# Processing Record 25 of Set 15 | polovinnoye
# Processing Record 26 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 15 | akureyri
# Processing Record 28 of Set 15 | kurikka
# Processing Record 29 of Set 15 | huarmey
# Processing Record 30 of Set 15 | twentynine palms
# Processing Record 31 of Set 15 | longyearbyen
# Processing Record 32 of Set 15 | marsh harbour
# Processing Record 33 of Set 15 | kathu
# Processing Record 34 of Set 15 | tarko-sale
# Processing Record 35 of Set 15 | colesberg
# Processing Record 36 of Set 15 | gamba
# Processing Record 37 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 15 | puerto escondido
# Processing Record 39 of Set 15 | lexington park
# Processing Record 40 of Set 15 | jiayuguan
# Processing Record 41 of Set 15 | phu ly
# Processing Record 42 of Set 15 | obong
# Processing Record 43 of Set 15 | iwanai
# Processing Record 44 of Set 15 | guapore
# Processing Record 45 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 15 | panguna
# Processing Record 47 of Set 15 | ondjiva
# Processing Record 48 of Set 15 | riverton
# Processing Record 49 of Set 15 | ta khmau
# Processing Record 50 of Set 15 | cortez
# Processing Record 1 of Set 16 | amapa
# Processing Record 2 of Set 16 | mana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Min Temp  Humidity  \
# 0          Albany      US  42.60  -73.97     68.00     66.00        91
# 1          Atuona      PF  -9.80 -139.03     78.13     78.13        78
# 2         Mataura      NZ -46.19  168.86     60.01     60.01        72
# 3  Senador Pompeu      BR  -5.59  -39.37     71.91     71.91        82
# 4        Cherskiy      RU  68.75  161.30     39.36     39.36        93
# 5           Pevek      RU  69.70  170.31     37.94     37.94        96
# 6        Thompson      CA  55.74  -97.86     53.60     53.60       100
# 7         Fortuna      US  40.60 -124.16     57.99     55.40        93
# 8       Cape Town      ZA -33.93   18.42     57.99     55.00        93
# 9     Guasdualito      VE   7.24  -70.73     72.84     72.84        97
#
#    Cloudiness  Wind Speed Current Description
# 0          41        1.97          light rain
# 1           5       17.05           clear sky
# 2          50        0.74          light rain
# 3          14        3.40          few clouds
# 4         100        8.81          light rain
# 5         100        2.89          light rain
# 6          90        6.93          light rain
# 7          90        6.93     overcast clouds
# 8          20       11.41          few clouds
# 9          82        3.09       moderate rain

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
